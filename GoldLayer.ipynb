# %%
import synapse.ml.core
from synapse.ml.services import AnalyzeText
# Out:
# StatementMeta(, ae527d7c-a6c7-4393-8b0d-1362e3f08599, 3, Finished, Available, Finished)

# %%
df = spark.sql('select * from ForYouTube.silvernews')
#display(df)
# Out:
# StatementMeta(, ae527d7c-a6c7-4393-8b0d-1362e3f08599, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, c20497b8-7661-4727-b8a8-19bef6ce79bc)

# %%
# Import the model and configure input and output columns

model = (AnalyzeText()
        .setTextCol('description')
        .setKind('SentimentAnalysis')
        .setOutputCol('response')
        .setErrorCol('error'))
# Out:
# StatementMeta(, ae527d7c-a6c7-4393-8b0d-1362e3f08599, 6, Finished, Available, Finished)

# %%
result = model.transform(df)
#display(result)
# Out:
# StatementMeta(, ae527d7c-a6c7-4393-8b0d-1362e3f08599, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ff00fe0e-5bc1-4c7d-a600-5dba5945b9c1)

# %%
from pyspark.sql.functions import col
sentiment_df = result.withColumn('sentiment', col('response.documents.sentiment'))
#display(sentiment_df)
# Out:
# StatementMeta(, ae527d7c-a6c7-4393-8b0d-1362e3f08599, 8, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 563f6aa1-5b34-4107-bde0-9898ef47aa8c)

# %%
sentiment_df.write.mode('append').saveAsTable('Final_Data')
# Out:
# StatementMeta(, ae527d7c-a6c7-4393-8b0d-1362e3f08599, 9, Finished, Available, Finished)
